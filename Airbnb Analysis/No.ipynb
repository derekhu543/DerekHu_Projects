# %%
import pandas as pd

# %%
data1 = pd.read_csv('../Project_5/application_record.csv')

# %%
data2 = pd.read_csv('../Project_5/credit_record.csv')

# %%
data1.head()
# Out:
#         ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804           M            Y               Y             0
# 1  5008805           M            Y               Y             0
# 2  5008806           M            Y               Y             0
# 3  5008808           F            N               Y             0
# 4  5008809           F            N               Y             0
#
#    AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0          427500.0               Working               Higher education
# 1          427500.0               Working               Higher education
# 2          112500.0               Working  Secondary / secondary special
# 3          270000.0  Commercial associate  Secondary / secondary special
# 4          270000.0  Commercial associate  Secondary / secondary special
#
#      NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# ...

# %%
data2.head()
# Out:
#         ID  MONTHS_BALANCE STATUS
# 0  5001711               0      X
# 1  5001711              -1      0
# 2  5001711              -2      0
# 3  5001711              -3      0
# 4  5001712               0      C

# %%
data1.shape
# Out:
# (438557, 18)

# %%
data2.shape
# Out:
# (1048575, 3)

# %%
data = pd.merge(data1, data2, how='left', on='ID')

# %%
data
# Out:
#               ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0        5008804           M            Y               Y             0
# 1        5008804           M            Y               Y             0
# 2        5008804           M            Y               Y             0
# 3        5008804           M            Y               Y             0
# 4        5008804           M            Y               Y             0
# ...          ...         ...          ...             ...           ...
# 1179810  6840104           M            N               Y             0
# 1179811  6840222           F            N               N             0
# 1179812  6841878           F            N               N             0
# 1179813  6842765           F            N               Y             0
# 1179814  6842885           F            N               Y             0
#
#          AMT_INCOME_TOTAL      NAME_INCOME_TYPE  \
# 0                427500.0               Working
# ...

# %%
data = data.dropna()

# %%
data
# Out:
#               ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 31       5008806           M            Y               Y             0
# 32       5008806           M            Y               Y             0
# 33       5008806           M            Y               Y             0
# 34       5008806           M            Y               Y             0
# 35       5008806           M            Y               Y             0
# ...          ...         ...          ...             ...           ...
# 1176066  5150337           M            N               Y             0
# 1176067  5150337           M            N               Y             0
# 1176068  5150337           M            N               Y             0
# 1176069  5150337           M            N               Y             0
# 1176070  5150337           M            N               Y             0
#
#          AMT_INCOME_TOTAL NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...
